# %% [markdown]
# <a href="https://colab.research.google.com/github/danielphilip12/NYPD-Arrest-Data-Year-to-Date-/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # Imports the python pandas library as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Projects/NYPD Crime Data/data/NYPD_Arrest_Data__Year_to_Date_.csv') # reads the csv file as a dataframe.
df.head() # displays the first 5 rows of the dataframe.
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   299458003  01/14/2025    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1   298855625  01/03/2025    847  NY STATE LAWS,UNCLASSIFIED FEL  125.0
# 2   298909765  01/05/2025    729  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
# 3   298969870  01/06/2025    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# 4   299329792  01/12/2025    101                       ASSAULT 3  344.0
#
#                       OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                       ROBBERY  PL 1601502          F           B
# 1              OTHER STATE LAWS  VTL05110FE          F           M
# 2                       FORGERY  PL 1702500          F           Q
# 3                FELONY ASSAULT  PL 1200501          F           B
# 4  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           K
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX PERP_RACE  \
# ...
